# %%
#optimized code using
#Phase	Description
# Phase 1	Trains only the classification head (base frozen)
# Phase 2	Fine-tunes top Xception layers (last ~30%)
# Optimizer	Adam with learning rate 1e-4 → 1e-5
# Input Size	Adapted to 224x224
# Accuracy Graph	Combines both training phases

import tensorflow as tf
from tensorflow.keras.applications import Xception
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cv2

# Parameters
input_shape = (224, 224, 3)
num_classes = 6
batch_size = 32
epochs_initial = 10  # Initial training with frozen layers
epochs_finetune = 10  # Fine-tuning after unfreezing

# Load base Xception model
base_model = Xception(weights='imagenet', include_top=False, input_shape=input_shape)
base_model.trainable = False  # Initial freeze

# Build classification head
x = layers.GlobalAveragePooling2D()(base_model.output)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output = layers.Dense(num_classes, activation='softmax')(x)

model = models.Model(inputs=base_model.input, outputs=output)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Custom preprocessing function for HSV
def preprocess_hsv(img):
    img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    return img / 255.0

train_datagen = ImageDataGenerator(preprocessing_function=preprocess_hsv)
val_datagen   = ImageDataGenerator(preprocessing_function=preprocess_hsv)
test_datagen  = ImageDataGenerator(preprocessing_function=preprocess_hsv)


# Dataset paths
train_dir = '/kaggle/input/diffmango224x224/AMBADIFUSEDATASET224X224/train'
val_dir   = '/kaggle/input/diffmango224x224/AMBADIFUSEDATASET224X224/val'
test_dir  = '/kaggle/input/diffmango224x224/AMBADIFUSEDATASET224X224/test'

# Load data
train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(224, 224), batch_size=batch_size, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(
    val_dir, target_size=(224, 224), batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(
    test_dir, target_size=(224, 224), batch_size=batch_size, class_mode='categorical', shuffle=False)

# ==============================
# 🔧 Phase 1: Train Frozen Model
# ==============================
print("\n🔧 Phase 1: Training with frozen base model...")
history1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs_initial
)

# ==============================
# 🔧 Phase 2: Fine-tune Model
# ==============================
print("\n🔧 Phase 2: Fine-tuning the base model...")
base_model.trainable = True
# Freeze first ~100 layers, fine-tune rest
for layer in base_model.layers[:100]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),  # Lower LR for fine-tuning
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs_finetune
)

# Merge training histories
history = {
    'accuracy': history1.history['accuracy'] + history2.history['accuracy'],
    'val_accuracy': history1.history['val_accuracy'] + history2.history['val_accuracy']
}

# 🎯 Evaluate on test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"\n✅ Test Accuracy after fine-tuning HSV: {test_accuracy:.4f}")

# 🔍 Predict & report
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print("\n📄 Classification Report LDM_Xception HSV:")
print(classification_report(y_true, y_pred, target_names=class_names))

# 📊 Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix LDM_Xception HSV')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# 📈 Accuracy plot
plt.figure(figsize=(12, 6))
plt.plot(history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history['val_accuracy'], label='Validation Accuracy', marker='s')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy LDM_Xception HSV')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2025-07-21 16:21:11.877852: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753114872.073532      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753114872.131223      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1753114885.464167      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# ...
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ...

# %%
#optimized code using
#Phase	Description
# Phase 1	Trains only the classification head (base frozen)
# Phase 2	Fine-tunes top Xception layers (last ~30%)
# Optimizer	Adam with learning rate 1e-4 → 1e-5
# Input Size	Adapted to 224x224
# Accuracy Graph	Combines both training phases

import tensorflow as tf
from tensorflow.keras.applications import Xception
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cv2

# Parameters
input_shape = (224, 224, 3)
num_classes = 6
batch_size = 32
epochs_initial = 10  # Initial training with frozen layers
epochs_finetune = 10  # Fine-tuning after unfreezing

# Load base Xception model
base_model = Xception(weights='imagenet', include_top=False, input_shape=input_shape)
base_model.trainable = False  # Initial freeze

# Build classification head
x = layers.GlobalAveragePooling2D()(base_model.output)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output = layers.Dense(num_classes, activation='softmax')(x)

model = models.Model(inputs=base_model.input, outputs=output)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()


# Custom preprocessing function for LAB
def preprocess_lab(img):
    img = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
    return img / 255.0

train_datagen = ImageDataGenerator(preprocessing_function=preprocess_lab)
val_datagen   = ImageDataGenerator(preprocessing_function=preprocess_lab)
test_datagen  = ImageDataGenerator(preprocessing_function=preprocess_lab)


# Dataset paths
train_dir = '/kaggle/input/diffmango224x224/AMBADIFUSEDATASET224X224/train'
val_dir   = '/kaggle/input/diffmango224x224/AMBADIFUSEDATASET224X224/val'
test_dir  = '/kaggle/input/diffmango224x224/AMBADIFUSEDATASET224X224/test'

# Load data
train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(224, 224), batch_size=batch_size, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(
    val_dir, target_size=(224, 224), batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(
    test_dir, target_size=(224, 224), batch_size=batch_size, class_mode='categorical', shuffle=False)

# ==============================
# 🔧 Phase 1: Train Frozen Model
# ==============================
print("\n🔧 Phase 1: Training with frozen base model...")
history1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs_initial
)

# ==============================
# 🔧 Phase 2: Fine-tune Model
# ==============================
print("\n🔧 Phase 2: Fine-tuning the base model...")
base_model.trainable = True
# Freeze first ~100 layers, fine-tune rest
for layer in base_model.layers[:100]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),  # Lower LR for fine-tuning
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs_finetune
)

# Merge training histories
history = {
    'accuracy': history1.history['accuracy'] + history2.history['accuracy'],
    'val_accuracy': history1.history['val_accuracy'] + history2.history['val_accuracy']
}

# 🎯 Evaluate on test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"\n✅ Test Accuracy after fine-tuning LAB: {test_accuracy:.4f}")

# 🔍 Predict & report
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print("\n📄 Classification Report LDM_Xception LAB:")
print(classification_report(y_true, y_pred, target_names=class_names))

# 📊 Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix LDM_Xception LAB')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# 📈 Accuracy plot
plt.figure(figsize=(12, 6))
plt.plot(history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history['val_accuracy'], label='Validation Accuracy', marker='s')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy LDM_Xception LAB')
plt.legend()
plt.grid(True)
plt.show()

# %%
#optimized code using
#Phase	Description
# Phase 1	Trains only the classification head (base frozen)
# Phase 2	Fine-tunes top Xception layers (last ~30%)
# Optimizer	Adam with learning rate 1e-4 → 1e-5
# Input Size	Adapted to 224x224
# Accuracy Graph	Combines both training phases

import tensorflow as tf
from tensorflow.keras.applications import Xception
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cv2

# Parameters
input_shape = (224, 224, 3)
num_classes = 6
batch_size = 32
epochs_initial = 10  # Initial training with frozen layers
epochs_finetune = 10  # Fine-tuning after unfreezing

# Load base Xception model
base_model = Xception(weights='imagenet', include_top=False, input_shape=input_shape)
base_model.trainable = False  # Initial freeze

# Build classification head
x = layers.GlobalAveragePooling2D()(base_model.output)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output = layers.Dense(num_classes, activation='softmax')(x)

model = models.Model(inputs=base_model.input, outputs=output)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()


# Custom preprocessing function for LAB
def preprocess_lab(img):
    img = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
    return img / 255.0

train_datagen = ImageDataGenerator(preprocessing_function=preprocess_lab)
val_datagen   = ImageDataGenerator(preprocessing_function=preprocess_lab)
test_datagen  = ImageDataGenerator(preprocessing_function=preprocess_lab)


# Dataset paths
train_dir = '/kaggle/input/diffmango224x224/AMBADIFUSEDATASET224X224/train'
val_dir   = '/kaggle/input/diffmango224x224/AMBADIFUSEDATASET224X224/val'
test_dir  = '/kaggle/input/diffmango224x224/AMBADIFUSEDATASET224X224/test'

# Load data
train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(224, 224), batch_size=batch_size, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(
    val_dir, target_size=(224, 224), batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(
    test_dir, target_size=(224, 224), batch_size=batch_size, class_mode='categorical', shuffle=False)

# ==============================
# 🔧 Phase 1: Train Frozen Model
# ==============================
print("\n🔧 Phase 1: Training with frozen base model...")
history1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs_initial
)

# ==============================
# 🔧 Phase 2: Fine-tune Model
# ==============================
print("\n🔧 Phase 2: Fine-tuning the base model...")
base_model.trainable = True
# Freeze first ~100 layers, fine-tune rest
for layer in base_model.layers[:100]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),  # Lower LR for fine-tuning
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs_finetune
)

# Merge training histories
history = {
    'accuracy': history1.history['accuracy'] + history2.history['accuracy'],
    'val_accuracy': history1.history['val_accuracy'] + history2.history['val_accuracy']
}

# 🎯 Evaluate on test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"\n✅ Test Accuracy after fine-tuning LAB: {test_accuracy:.4f}")

# 🔍 Predict & report
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print("\n📄 Classification Report LDM_Xception LAB:")
print(classification_report(y_true, y_pred, target_names=class_names))

# 📊 Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix LDM_Xception LAB')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# 📈 Accuracy plot
plt.figure(figsize=(12, 6))
plt.plot(history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history['val_accuracy'], label='Validation Accuracy', marker='s')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy LDM_Xception LAB')
plt.legend()
plt.grid(True)
plt.show()
