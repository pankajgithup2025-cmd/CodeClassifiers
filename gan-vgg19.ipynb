# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# Load the VGG19 model without the top (fully connected) layers
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze all convolutional layers
for layer in base_model.layers:
    layer.trainable = False

# Flatten the output of the convolutional base
x = Flatten()(base_model.output)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)  # Add dropout to reduce overfitting
x = Dense(6, activation='softmax')(x)  # 6-class classification

# Create the new model
model = Model(inputs=base_model.input, outputs=x)

# Compile the model
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy',  # Multi-class classification
    metrics=['accuracy']
)

# Print the model summary
model.summary()

# Define ImageDataGenerator without augmentation
train_datagen = ImageDataGenerator(rescale=1./255)  # Only rescale for training
val_datagen = ImageDataGenerator(rescale=1./255)    # Only rescale for validation
test_datagen = ImageDataGenerator(rescale=1./255)   # Only rescale for test

# Load Training Data
train_generator = train_datagen.flow_from_directory(
    '/kaggle/input/ganmango224x224/GANDataset224X224/train',   # Path to train folder
    target_size=(224, 224), 
    batch_size=32,
    class_mode='categorical'  # Multi-class classification (8 classes)
)

# Load Validation Data
val_generator = val_datagen.flow_from_directory(
    '/kaggle/input/ganmango224x224/GANDataset224X224/val',   # Path to validation folder
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Load Test Data (For final evaluation)
test_generator = test_datagen.flow_from_directory(
    '/kaggle/input/ganmango224x224/GANDataset224X224/test',   # Path to test folder
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False   # No shuffling for test set
)

# Train the Model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=30  # You can adjust the number of epochs as needed
)

# Plot Training & Validation Accuracy
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='s')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy VGG19 with StyleGAN3 Aug')
plt.legend()
plt.grid(True)
plt.show()

# Evaluate on test data
test_loss, test_acc = model.evaluate(test_generator)
print(f"\nTest Accuracy: {test_acc:.4f}")

# Confusion matrix and classification report
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Classification report
print("\nClassification Report VGG19 with StyleGAN3 Aug:")
print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_generator.class_indices.keys())
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - VGG19 with StyleGAN3 Aug")
plt.show()
# Out:
# 2025-06-04 13:17:33.433935: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749043053.661631      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749043053.716555      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1749043067.081159      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1749043067.081800      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv4 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       6,422,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 6)                   │           1,542 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,448,710 (100.89 MB)
#  Trainable params: 6,424,326 (24.51 MB)
#  Non-trainable params: 20,024,384 (76.39 MB)
# Found 42000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# Found 9000 images belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749043117.198235     100 service.cc:148] XLA service 0x7d723c00fa80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749043117.199186     100 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1749043117.199209     100 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1749043117.662164     100 cuda_dnn.cc:529] Loaded cuDNN version 90300
#    1/1313 ━━━━━━━━━━━━━━━━━━━━ 5:16:23 14s/step - accuracy: 0.2188 - loss: 2.0159
# I0000 00:00:1749043129.085735     100 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 531s 393ms/step - accuracy: 0.7331 - loss: 0.8746 - val_accuracy: 0.9349 - val_loss: 0.1826
# Epoch 2/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 377s 287ms/step - accuracy: 0.8627 - loss: 0.3546 - val_accuracy: 0.9612 - val_loss: 0.1294
# Epoch 3/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 287ms/step - accuracy: 0.8845 - loss: 0.3018 - val_accuracy: 0.9747 - val_loss: 0.0800
# Epoch 4/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 287ms/step - accuracy: 0.9009 - loss: 0.2641 - val_accuracy: 0.9636 - val_loss: 0.0983
# Epoch 5/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 287ms/step - accuracy: 0.9093 - loss: 0.2403 - val_accuracy: 0.9814 - val_loss: 0.0590
# Epoch 6/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 286ms/step - accuracy: 0.9127 - loss: 0.2319 - val_accuracy: 0.9826 - val_loss: 0.0606
# Epoch 7/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 286ms/step - accuracy: 0.9152 - loss: 0.2215 - val_accuracy: 0.9814 - val_loss: 0.0564
# Epoch 8/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 286ms/step - accuracy: 0.9242 - loss: 0.2010 - val_accuracy: 0.9838 - val_loss: 0.0507
# Epoch 9/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 286ms/step - accuracy: 0.9172 - loss: 0.2181 - val_accuracy: 0.9798 - val_loss: 0.0620
# Epoch 10/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 286ms/step - accuracy: 0.9271 - loss: 0.1902 - val_accuracy: 0.9822 - val_loss: 0.0562
# Epoch 11/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 287ms/step - accuracy: 0.9219 - loss: 0.1977 - val_accuracy: 0.9829 - val_loss: 0.0525
# Epoch 12/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 286ms/step - accuracy: 0.9275 - loss: 0.1851 - val_accuracy: 0.9870 - val_loss: 0.0417
# Epoch 13/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 286ms/step - accuracy: 0.9288 - loss: 0.1841 - val_accuracy: 0.9831 - val_loss: 0.0505
# Epoch 14/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 380s 289ms/step - accuracy: 0.9286 - loss: 0.1858 - val_accuracy: 0.9833 - val_loss: 0.0545
# Epoch 15/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 285ms/step - accuracy: 0.9290 - loss: 0.1834 - val_accuracy: 0.9882 - val_loss: 0.0383
# Epoch 16/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 286ms/step - accuracy: 0.9208 - loss: 0.1953 - val_accuracy: 0.9876 - val_loss: 0.0428
# Epoch 17/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 377s 287ms/step - accuracy: 0.9296 - loss: 0.1784 - val_accuracy: 0.9848 - val_loss: 0.0473
# Epoch 18/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 286ms/step - accuracy: 0.9329 - loss: 0.1749 - val_accuracy: 0.9871 - val_loss: 0.0426
# Epoch 19/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 286ms/step - accuracy: 0.9222 - loss: 0.1950 - val_accuracy: 0.9849 - val_loss: 0.0502
# Epoch 20/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 286ms/step - accuracy: 0.9209 - loss: 0.2037 - val_accuracy: 0.9867 - val_loss: 0.0449
# Epoch 21/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 286ms/step - accuracy: 0.9279 - loss: 0.2074 - val_accuracy: 0.9844 - val_loss: 0.0455
# Epoch 22/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 286ms/step - accuracy: 0.9249 - loss: 0.2114 - val_accuracy: 0.9872 - val_loss: 0.0394
# Epoch 23/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 286ms/step - accuracy: 0.9264 - loss: 0.2038 - val_accuracy: 0.9838 - val_loss: 0.0532
# Epoch 24/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 286ms/step - accuracy: 0.9287 - loss: 0.2003 - val_accuracy: 0.9842 - val_loss: 0.0571
# Epoch 25/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 286ms/step - accuracy: 0.9293 - loss: 0.1983 - val_accuracy: 0.9858 - val_loss: 0.0511
# Epoch 26/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 285ms/step - accuracy: 0.9279 - loss: 0.2024 - val_accuracy: 0.9850 - val_loss: 0.0487
# Epoch 27/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 286ms/step - accuracy: 0.9327 - loss: 0.1914 - val_accuracy: 0.9879 - val_loss: 0.0414
# Epoch 28/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 285ms/step - accuracy: 0.9324 - loss: 0.1930 - val_accuracy: 0.9818 - val_loss: 0.0671
# Epoch 29/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 376s 286ms/step - accuracy: 0.9344 - loss: 0.1868 - val_accuracy: 0.9871 - val_loss: 0.0455
# Epoch 30/30
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 285ms/step - accuracy: 0.9342 - loss: 0.1858 - val_accuracy: 0.9826 - val_loss: 0.0698
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 90s 321ms/step - accuracy: 0.9902 - loss: 0.0428
#
# Test Accuracy: 0.9831
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 66s 232ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/3510213885.py in <cell line: 0>()
#      88 y_true = test_generator.classes
#      89 y_pred_probs = model.predict(test_generator)
# ---> 90 y_pred = np.argmax(y_pred_probs, axis=1)
#      91
#      92 # Classification report
#
# NameError: name 'np' is not defined

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
# Confusion matrix and classification report
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
# Classification Report
print("\n📊 Classification Report VGG19 with StyleGAN3 Aug:")
target_names = list(test_generator.class_indices.keys())
print(classification_report(y_true, y_pred, target_names=target_names))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_generator.class_indices.keys())
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - VGG19 with StyleGAN3 Aug")
plt.show()
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 66s 232ms/step
#
# 📊 Classification Report VGG19 with StyleGAN3 Aug:
#                     precision    recall  f1-score   support
#
#        ANTHRECNOSE       0.98      0.99      0.99      1500
#            DIEBACK       0.99      1.00      0.99      1500
#   GALLMILDGEDAMAGE       0.99      0.99      0.99      1500
#            HEALTHY       0.99      0.98      0.99      1500
# INSECTDAMAGEWEBBER       0.98      0.96      0.97      1500
#         LEAFBLIGHT       0.97      0.98      0.97      1500
#
#           accuracy                           0.98      9000
#          macro avg       0.98      0.98      0.98      9000
#       weighted avg       0.98      0.98      0.98      9000
